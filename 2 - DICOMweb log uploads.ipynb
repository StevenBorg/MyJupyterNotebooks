# %%
import os
import requests
import io
import pandas as pd
import pydicom
from pathlib import Path
import time

from pydicom.dataset import Dataset as DcmDataset
from pydicom.tag import BaseTag as DcmTag
from pydicom.multival import MultiValue as DcmMultiValue

#see https://stackoverflow.com/questions/15746558/how-to-send-a-multipart-related-with-requests-in-python

#from fastcore.foundation import * #Patch here (but also imports fastcore.imports (which is not sufficient))
    # But parallel is NOT here... :-(

from fastai2.data.all import *
#from fastai2 import *

# %%
#url = "https://dicom-server-instance.azurewebsites.net/studies"
url = "https://sjbdicomdemo.azurewebsites.net/studies"

dicom_server_name = "tonydicom"
url = f"https://{dicom_server_name}.azurewebsites.net/studies"
url
# Out:
# 'https://tonydicom.azurewebsites.net/studies'

# %%
# Cell
@patch
def dcmread(fn:Path, force = False): #, force = False):
    "Open a `DICOM` file"
    return pydicom.dcmread(str(fn), force)

# Cell
def _cast_dicom_special(x):
    cls = type(x)
    if not cls.__module__.startswith('pydicom'): return x
    if cls.__base__ == object: return x
    return cls.__base__(x)

def _split_elem(res,k,v):
    if not isinstance(v,DcmMultiValue): return
    res[f'Multi{k}'] = 1
    for i,o in enumerate(v): res[f'{k}{"" if i==0 else i}']=o

        # Cell
@patch
def as_dict(self:DcmDataset, px_summ=False): #, window=dicom_windows.brain):
    pxdata = (0x7fe0,0x0010)
    vals = [self[o] for o in self.keys() if o != pxdata]
    its = [(v.keyword,v.value) for v in vals]
    res = dict(its)
    res['fname'] = self.filename
    for k,v in its: _split_elem(res,k,v)
    if not px_summ: return res
    stats = 'min','max','mean','std'
#    try:
#        pxs = self.pixel_array
#        for f in stats: res['img_'+f] = getattr(pxs,f)()
#        res['img_pct_window'] = self.pct_in_window(*window)
#    except Exception as e:
#        for f in stats: res['img_'+f] = 0
#        print(res,e)
    for k in res: res[k] = _cast_dicom_special(res[k])
    return res

# Cell
def _dcm2dict(fn, **kwargs): return fn.dcmread().as_dict(**kwargs)

# Cell
@delegates(parallel)
def _from_dicoms(cls, fns, n_workers=0, **kwargs):
    return pd.DataFrame(parallel(_dcm2dict, fns, n_workers=n_workers, **kwargs))
pd.DataFrame.from_dicoms = classmethod(_from_dicoms)

# %%
# Validate goes beyond checking the dicom header, but attempts a actually load every single file into a Pydicom Dataset
#    This later step has shown effective for ensuring that the metadata can be loaded into a dataset
def get_dicom_files_from_directory(dirpath,extension="*.dcm", validate=False):
    path = Path(dirpath) 
    # pydicom 2 has an is_valid method to replace is_dicom (maybe look at pydicom2 for other reasons)
    files = [x for x in path.rglob(extension)] # if pydicom.misc.is_dicom(str(x))] # checks for DICM in header (fast and loose)
    if validate:
        for file in files[:]:
            #pydicom.validate() #is this only in pydicom 2?
            try:
                #print(file)
                x = dcmread(file)           
            except:
                # remove file if it throws an exception
                files.remove(x)
    #Potentially look at pydicom.dataset.validate_file_meta(file_meta, enforce_standard=True) for deeper validation
    #  https://pydicom.github.io/pydicom/dev/reference/generated/pydicom.dataset.validate_file_meta.html
    return files

# %%
#files = get_dicom_files_from_directory('C:\\githealth\\hackathon-dataset\\hackathon-images', validate=False) # all succeed
#files = get_dicom_files_from_directory('C:\\githealth\\dicom-samples\\rubomedica.com') #all succeed
#files = get_dicom_files_from_directory('C:\\githealth\\dicom-samples\\barre.dev') #409 and 500 errors on first upload
#files = get_dicom_files_from_directory('C:\\githealth\\dicom-samples\\dicomlibrary.com\\series-000001') #409 and 500 errors on first upload
#files = get_dicom_files_from_directory('C:\\!!delete4DLung', validate=False)
#files = get_dicom_files_from_directory('C:\\!DicomDataTCIA\\4D-Lung', validate=False)
#files = get_dicom_files_from_directory('C:\\githealth\\elastic-cast-reduced\\hackathon-images', validate=False)
files = get_dicom_files_from_directory('C:\\!!delete4DLung', validate=False)

print(len(files))
# Out:
# 866

# %%
files = [x for x in files if not 'pydicom' in str(x)]
print(len(files))
# Out:
# 866

# %%
# Can just use this to load all the files in a directory, instead of calling above
#dirname = 'C:\\githealth\\dicom-samples\\visus.com'
#files = [x for x in Path(dirname).rglob('*.dcm')] # if not 'pydicom' in str(x)] # exclude pydicom test files

# %%
# Stupid simple function to get a Dataframe, but can be extended later to add logic
def get_dicom_metadata_as_dataframe(list_of_files,columns=[],save_as_filename=''):
    df = pd.DataFrame.from_dicoms(files)
    if save_as_filename != '':
        df.to_csv(save_as_filename)
    return df

# %%
## The following goes and gets metadata for 4d-lung

# %%
len(files)
# Out:
# 866

# %%
#df = pd.DataFrame.from_dicoms(files)
#df.to_csv('TestDicom2.csv')

# %%
df = get_dicom_metadata_as_dataframe(files)

# %%
df.to_csv('4D_lung_metadata.csv')

# %%
from urllib3.filepost import encode_multipart_formdata, choose_boundary

def encode_multipart_related(fields, boundary=None):
    if boundary is None:
        boundary = choose_boundary()

    body, _ = encode_multipart_formdata(fields, boundary)
    content_type = str('multipart/related; boundary=%s' % boundary)

    return body, content_type

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
def upload_single_dcm_file(server_url,filepath):
    with open(filepath,'rb') as reader:
        rawfile = reader.read()
    files = {'file': ('dicomfile', rawfile, 'application/dicom')}

    #encode as multipart_related
    body, content_type = encode_multipart_related(fields = files)
    
    headers = {'Accept':'application/dicom+json', "Content-Type":content_type}

    response = requests.post(url, body, headers=headers) #, verify=False)
    
    #return the response object to allow for further processing
    
    #example usage
    #r = upload_single_dcm_file(url,'C:\\githealth\\dicom-samples\\visus.com\\case4\\case4a_002.dcm')
    #print(r.status_code)
    #print(r.request.headers)
    
    return response

# %%
#r = upload_dcm_file(url,'C:\\githealth\\dicom-samples\\visus.com\\case4\\case4a_002.dcm')
#print(r.status_code)
#print(r.request.headers)

# %%
from collections import OrderedDict
def store_files_to_dicomweb_with_logging_to_dataframe(filepaths, df = None):
    if df is None:
        # Then we have a blank dataframe, maybe do something here.
        #   for now, I'm just using a blank one.
        #columns = ['fname','status_code','response_notes']
        df = pd.DataFrame()
        df['fname']=filepaths
    
    # Fastest to just use lists and dictionaries then create a new dataframe from that...
    numfiles=len(filepaths)
    current_count=0
    
    files_info = []
    for file in filepaths:
        
        # Upload a single file at a time (and time it)
        r = upload_single_dcm_file(url,file)     # call API and get response 
        d = OrderedDict()   # create a new ordered dictionary
        
        # Add the information to the dictionary
        d['fname'] = str(file)     
        d['method'] = r.request.method
        d['url'] = r.url
        d['path_url'] = r.request.path_url
        d['request_headers'] = str(r.request.headers)
        d['request_body_trimmed'] = r.request.body[0:150]   

        d['ok'] = r.ok
        d['status_code'] = r.status_code  
        d['reason'] = r.reason
        d['response_headers'] = r.headers
        d['response_text'] = r.text  
        d['elapsed_time'] = r.elapsed
        d['apparent_encoding'] = r.apparent_encoding
        d['encoding'] = r.encoding
        
 
        files_info.append(d)
        current_count += 1
        if current_count%250==0:
            print(f"{current_count} of {numfiles} uploaded")

    # Create a dataframe from the uploads
    df = pd.DataFrame(files_info)               
    return df

# %%
df = store_files_to_dicomweb_with_logging_to_dataframe(files[:50])

# %%
df.head(15)
# Out:
#                                                                                                      fname  \
# 0   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-001.dcm
# 1   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-002.dcm
# 2   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-003.dcm
# 3   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-004.dcm
# 4   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-005.dcm
# 5   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-006.dcm
# 6   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-007.dcm
# 7   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-008.dcm
# 8   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-009.dcm
# 9   C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-010.dcm
# 10  C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-011.dcm
# 11  C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-012.dcm
# 12  C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-013.dcm
# 13  C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-014.dcm
# 14  C:\!!delete4DLung\100_HM10395\07-02-2003-p4-14571\1.000000-P4P100S300I00003 Gated 0.0A-29193\1-015.dcm
#
#    method                                          url  path_url  \
# 0    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 1    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 2    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 3    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 4    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 5    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 6    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 7    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 8    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 9    POST  https://tonydicom.azurewebsites.net/studies  /studies
# 10   POST  https://tonydicom.azurewebsites.net/studies  /studies
# 11   POST  https://tonydicom.azurewebsites.net/studies  /studies
# 12   POST  https://tonydicom.azurewebsites.net/studies  /studies
# 13   POST  https://tonydicom.azurewebsites.net/studies  /studies
# 14   POST  https://tonydicom.azurewebsites.net/studies  /studies
#
#                                                                                                                                                                                                                                              request_headers  \
# 0   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=f6ad605ce668bddde0082ebcc7c5c91f', 'Content-Length': '526496'}
# 1   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=805851cf9f1378104c2a47ad0c3596e8', 'Content-Length': '526496'}
# 2   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=b0d3372ba1133e05ec6f95e0db026422', 'Content-Length': '526496'}
# 3   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=1bcc752be5a9d559a8d48dd9f4a30cbb', 'Content-Length': '526496'}
# 4   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=4f4a12a71fc6b96f1e56afc930f6725c', 'Content-Length': '526496'}
# 5   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=575bd8e2a5a75ea106bda0ac2e9e078c', 'Content-Length': '526496'}
# 6   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=6cc33b546739cfd539b74d37956f3f27', 'Content-Length': '526496'}
# 7   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=829dd55041df5a5ade608a232854f4f1', 'Content-Length': '526496'}
# 8   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=1cbe745144cd256cc96fc7408c74162c', 'Content-Length': '526496'}
# 9   {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=4558d532f55da05207d17f330636cd55', 'Content-Length': '526496'}
# 10  {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=b2b218a4e30ea490e87cc6bac3967e4b', 'Content-Length': '526496'}
# 11  {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=958d094449040c42ca0a8deeaab54558', 'Content-Length': '526496'}
# 12  {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=10270445ac35b4feb7e0243deb4c87f9', 'Content-Length': '526496'}
# 13  {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=f82fb61f6aa7d81c728afef5e01c8b4b', 'Content-Length': '526496'}
# 14  {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/dicom+json', 'Connection': 'keep-alive', 'Content-Type': 'multipart/related; boundary=257d2ec92db30b6188a87e9b200ba283', 'Content-Length': '526496'}
#
#                                                                                                                                                                                      request_body_trimmed  \
# 0   b'--f6ad605ce668bddde0082ebcc7c5c91f\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 1   b'--805851cf9f1378104c2a47ad0c3596e8\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 2   b'--b0d3372ba1133e05ec6f95e0db026422\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 3   b'--1bcc752be5a9d559a8d48dd9f4a30cbb\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 4   b'--4f4a12a71fc6b96f1e56afc930f6725c\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 5   b'--575bd8e2a5a75ea106bda0ac2e9e078c\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 6   b'--6cc33b546739cfd539b74d37956f3f27\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 7   b'--829dd55041df5a5ade608a232854f4f1\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 8   b'--1cbe745144cd256cc96fc7408c74162c\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 9   b'--4558d532f55da05207d17f330636cd55\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 10  b'--b2b218a4e30ea490e87cc6bac3967e4b\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 11  b'--958d094449040c42ca0a8deeaab54558\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 12  b'--10270445ac35b4feb7e0243deb4c87f9\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 13  b'--f82fb61f6aa7d81c728afef5e01c8b4b\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# 14  b'--257d2ec92db30b6188a87e9b200ba283\r\nContent-Disposition: form-data; name="file"; filename="dicomfile"\r\nContent-Type: application/dicom\r\n\r\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
#
#       ok  status_code reason  \
# 0   True          200     OK
# 1   True          200     OK
# 2   True          200     OK
# 3   True          200     OK
# 4   True          200     OK
# 5   True          200     OK
# 6   True          200     OK
# 7   True          200     OK
# 8   True          200     OK
# 9   True          200     OK
# 10  True          200     OK
# 11  True          200     OK
# 12  True          200     OK
# 13  True          200     OK
# 14  True          200     OK
#
#                                                                                        response_headers  \
# 0   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 1   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 2   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 3   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 4   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 5   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 6   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 7   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 8   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 9   [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 10  [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 11  [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 12  [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 13  [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
# 14  [Content-Length, Content-Type, Server, Request-Context, X-Content-Type-Options, X-Powered-By, Date]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                response_text  \
# 0   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.137738534451320802044707152865"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.137738534451320802044707152865"]}}]}}
# 1   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.281373012247438280161273217036"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.281373012247438280161273217036"]}}]}}
# 2   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.169241991802971349879591579789"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.169241991802971349879591579789"]}}]}}
# 3   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.152792994403709697716307370077"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.152792994403709697716307370077"]}}]}}
# 4   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.292466472618636828594833335663"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.292466472618636828594833335663"]}}]}}
# 5   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.533052719654757104158795931661"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.533052719654757104158795931661"]}}]}}
# 6   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.378119626956622931997638021137"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.378119626956622931997638021137"]}}]}}
# 7   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.154128964615638668864497826873"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.154128964615638668864497826873"]}}]}}
# 8   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.607914670755055068373946102132"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.607914670755055068373946102132"]}}]}}
# 9   {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.306045988762293487414795513612"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.306045988762293487414795513612"]}}]}}
# 10  {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.336693031277278889619934977745"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.336693031277278889619934977745"]}}]}}
# 11  {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.298464707342145327068613290491"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.298464707342145327068613290491"]}}]}}
# 12  {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.211215808965850196327209122217"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.211215808965850196327209122217"]}}]}}
# 13  {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.283243425014529818712078611234"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.283243425014529818712078611234"]}}]}}
# 14  {"00081199":{"vr":"SQ","Value":[{"00081150":{"vr":"UI","Value":["1.2.840.10008.5.1.4.1.1.2"]},"00081155":{"vr":"UI","Value":["1.3.6.1.4.1.14519.5.2.1.6834.5010.297881838903345737065681804057"]},"00081190":{"vr":"UR","Value":["https://tonydicom.azurewebsites.net/studies/1.3.6.1.4.1.14519.5.2.1.6834.5010.465205689126985052184293614571/series/1.3.6.1.4.1.14519.5.2.1.6834.5010.660205801121995704108596829193/instances/1.3.6.1.4.1.14519.5.2.1.6834.5010.297881838903345737065681804057"]}}]}}
#
#       elapsed_time apparent_encoding encoding
# 0  00:00:17.706963             ascii    utf-8
# 1  00:00:00.598966             ascii    utf-8
# 2  00:00:00.261323             ascii    utf-8
# 3  00:00:00.324483             ascii    utf-8
# 4  00:00:00.321377             ascii    utf-8
# 5  00:00:00.335556             ascii    utf-8
# 6  00:00:00.206839             ascii    utf-8
# 7  00:00:00.213439             ascii    utf-8
# 8  00:00:00.240203             ascii    utf-8
# 9  00:00:00.324868             ascii    utf-8
# 10 00:00:00.254623             ascii    utf-8
# 11 00:00:00.258976             ascii    utf-8
# 12 00:00:00.589476             ascii    utf-8
# 13 00:00:00.301296             ascii    utf-8
# 14 00:00:00.238901             ascii    utf-8

# %%
df.to_csv('4D_lung_upload.csv')

# %%
len(df)
# Out:
# 10

# %%
# The following is for chunked upload of larger directories

# %%
len(files)

# %%
def split_list(a_list, size):
     lists = []
     while len(a_list) > size:
         pice = a_list[:size]
         lists.append(pice)
         a_list = a_list[size:]
     lists.append(a_list)
     return lists

# %%
def process_file_subset(file_subset):
    #print(f'Processing {len(file_subset)} files')
    #df_meta = pd.DataFrame()
    #df_upload = pd.DataFrame() 
    df_meta = get_dicom_metadata_as_dataframe(file_subset)
    #df_meta.to_csv('c:\\!mlhack\\metadata-mlhack_train_subset.csv')
    df_upload = store_files_to_dicomweb_with_logging_to_dataframe(file_subset)
    #df_upload.to_csv('c:\\!mlhack\\upload-data-mlhack_train_subset.csv')
    return df_meta, df_upload

# %%
# Process all the files in chunks
batch_size = 250
df_meta = pd.DataFrame()
df_upload = pd.DataFrame()

groups_of_files = split_list(files,batch_size)

for i,group in enumerate(groups_of_files):
    print(f'Processing {i} of {len(groups_of_files)} groups with {len(group)} files each')
    df_meta_subset, df_upload_subset = process_file_subset(group)
    df_meta = pd.concat([df_meta,df_meta_subset])
    df_upload = pd.concat([df_upload,df_upload_subset])
    df_meta.to_csv('c:\\!mlhack\\metadata-mlhack_train_sofar.csv')
    df_upload.to_csv('c:\\!mlhack\\upload-data-mlhack_train_sofar.csv')

# %%
df_meta.to_csv('c:\\!mlhack\\metadata-mlhack_train.csv')
df_upload.to_csv('c:\\!mlhack\\upload-data-mlhack_train.csv')
